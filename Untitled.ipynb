# %%
import numpy as np
import pandas as pd
from classifier import *
from sklearn import datasets
import matplotlib.pyplot as plt
from scipy import optimize

# %%
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
def plot_decision_regions(X,y,clf,resolution=0.02):
    """
    The function plots decision regions on 2D plain given the data to plot: matrix X and vector y;
    and trained classifier clf. The data should be standarized.
    """
    
    # setting constants
    markers = ('s','x','o','^','v')
    colors = ('red','blue','lightgreen','gray','cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])
    
    # setting frame sizes
    x1_min, x1_max = X[:,0].min() - 0.25, X[:,0].max() + 0.25
    x2_min, x2_max = X[:,1].min() - 0.25, X[:,1].max() + 0.25
    
    # grid
    xx1,xx2 = np.meshgrid(np.arange(x1_min,x1_max,resolution),
                         np.arange(x2_min,x2_max,resolution))
    
    # prediction of every point on the grid
    Z = clf._predict(np.array([xx1.ravel(), xx2.ravel()]).transpose())
    Z = Z.reshape(xx1.shape)
    
    # filling regions
    plt.contourf(xx1,xx2,Z,alpha=0.4, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())
    
    # displaying points from X
    for idx, cl in  enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl,1],
                   alpha=0.8,c=cmap(idx),
                   marker=markers[idx],
                   label=cl, s=2)

# %%
X, Y = datasets.make_classification(n_samples=1000, n_features=2, n_redundant=0, class_sep=2)
Y = 2*Y - 1

# %%
plt.scatter(*X.T, c=Y)

# %% [markdown]
# # CMLS

# %%
model = CMLSClassifier()
model.fit(X, Y)

# %%
(model._predict(X) == Y).mean()
# Out:
# 0.722

# %%
plt.subplot(1, 2, 1)
plt.scatter(*X.T, c=Y)
plt.subplot(1, 2, 2)
plt.scatter(*X.T, c=model._predict(X))

# %%
plot_decision_regions(X, Y, model)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
def fun(x):
    return x**2 + 2*x + 1

def fun_der(x):
    return 2*x + 2

def fun_hess(x):
    return np.array([[2]])

# %%
def fun(x):
    return x**2 + 2*x + 1

def fun_der(x):
    return 2*x + 2

def fun_hess(x):
    return np.array([[2]])

# %%
res = optimize.minimize(fun, 0, method='trust-ncg', jac=fun_der, hess=fun_hess)

# %%
res.x
# Out:
# array([-1.])

# %%
[model.compute_D_derivative(i, 0)[0] for i in range(3)]
# Out:
# [-1009.9400897667283, -6619.859440598364, -9491.447654323429]

# %%
[model.compute_D_second_derivative(i, 0)[0] for i in range(3)]
# Out:
# [631.0, 2583.6464429266457, 3612.1827597826573]

# %%
d = np.array([model.compute_D_derivative(i, 0)[0] for i in range(model.p)])
d2 = np.array([model.compute_D_second_derivative(i, 0)[0] for i in range(model.p)])
q = lambda s: (d*s + 0.5 * s**2 * d2).sum()
s = minimize(
    fun=q,
    x0=np.zeros(model.p), method='trust-ncg',
    jac=lambda s: s*d2 + d,
    hess=lambda s: np.diag(d2)).x

# %% [markdown]
# # TRON

# %%
model = TrustRegionNewtonClassifier()
model.fit(X, Y)

# %%
(model._predict(X) == Y).mean()
# Out:
# 0.991

# %%
plt.subplot(1, 2, 1)
plt.scatter(*X.T, c=Y)
plt.subplot(1, 2, 2)
plt.scatter(*X.T, c=model._predict(X))

# %%
plot_decision_regions(X, Y, model)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
